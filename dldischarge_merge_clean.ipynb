# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
# MERGING MANUALLY COLLECTED DISCHARGE INTO CLEANED 7M-1 DATALOGGER DISCHARGE
s_7m = pd.read_excel('Discharge vs Stage 2022.xlsx')
s_7m = s_7m[['Date', 'Flow Rate (cfs)']]

S_7m = pd.read_csv('7M-1_SevenMile_Creek_at_Birdseye_Water_Level_clean.csv')
S_7m = S_7m.rename(columns={'Date, GMT-06:00':'Date'})
S_7m['Date'] = pd.to_datetime(S_7m['Date'])

new = pd.merge(S_7m, s_7m, on='Date', how='left')

# UPDATING CLEANED FILE
new.to_csv('7M-1_SevenMile_Creek_at_Birdseye_Water_Level_clean.csv')
# Out:
#         Date  Flow Rate (cfs)
# 0 2022-05-04              NaN
# 1 2022-05-11            3.910
# 2 2022-06-20            4.442
# 3 2022-07-28            1.705
# 4 2022-09-28            1.361
# 5 2022-10-28            1.969
# 6 2021-10-20            3.530
# 7 2021-08-09            4.120
# 8 2021-06-23            9.680
# 9 2021-06-15           13.060

# %%
# MERGING MANUALLY COLLECTED DISCHARGE INTO CLEANED P-2 DATALOGGER DISCHARGE
p_2 = pd.read_excel('Discharge vs Stage 2022.xlsx', sheet_name= 'P-2')
p_2 = p_2[['Date', 'Flow Rate (cfs)']]

P_2 = pd.read_csv('P2-20341750_clean.csv')
P_2 = P_2.rename(columns={'Date, GMT-06:00':'Date'})
P_2['Date'] = pd.to_datetime(P_2['Date'])

new = pd.merge(P_2, p_2, on='Date', how='left')

# UPDATING CLEANED FILE
new.to_csv('P2-20341750_clean.csv')

# %%
# MERGING MANUALLY COLLECTED DISCHARGE INTO CLEANED P-4 DATALOGGER DISCHARGE
p_4 = pd.read_excel('Discharge vs Stage 2022.xlsx', sheet_name= 'P-4')
p_4 = p_4[['Date', 'Flow Rate (cfs)']]

P_4 = pd.read_csv('P4_PPC_along_Wylie_Dr_clean.csv')
P_4 = P_4.rename(columns={'Date, GMT-06:00':'Date'})
P_4['Date'] = pd.to_datetime(P_4['Date'])


new = pd.merge(P_4, p_4, on='Date', how='left')

# UPDATING CLEANED FILE
new.to_csv('P4_PPC_along_Wylie_Dr_clean.csv')

# %%
# MERGING MANUALLY COLLECTED DISCHARGE INTO CLEANED DATALOGGER P-5 DISCHARGE
p_5 = pd.read_excel('Discharge vs Stage 2022.xlsx', sheet_name= 'P-5')
p_5 = p_5[['Date', 'Flow Rate (cfs)']]

P_5 = pd.read_csv('P5_PPC_@_Canyon_Ferry_Rd_clean.csv')
P_5 = P_5.rename(columns={'Date, GMT-06:00':'Date'})
P_5['Date'] = pd.to_datetime(P_5['Date'])

new = pd.merge(P_5, p_5, on='Date', how='left')

# UPDATING CLEANED FILE
new.to_csv('P5_PPC_@_Canyon_Ferry_Rd_clean.csv')

# %%
# MERGING MANUALLY COLLECTED DISCHARGE INTO CLEANED DATALOGGER P-7 DISCHARGE
p_7 = pd.read_excel('Discharge vs Stage 2022.xlsx', sheet_name= 'P-7')
p_7 = p_7[['Date', 'Flow Rate (cfs)']]

P_7 = pd.read_csv('P-7_PPC_at_FAS_York_Rd_clean.csv')
P_7 = P_7.rename(columns={'Date, GMT-06:00':'Date'})
P_7['Date'] = pd.to_datetime(P_7['Date'])

new = pd.merge(P_7, p_7, on='Date', how='left')

# UPDATING CLEANED FILE
new.to_csv('P-7_PPC_at_FAS_York_Rd_clean.csv')

# %%
# MERGING MANUALLY COLLECTED DISCHARGE INTO CLEANED DATALOGGER P-10 DISCHARGE
p_10 = pd.read_excel('Discharge vs Stage 2022.xlsx', sheet_name= 'P-10')
p_10 = p_10[['Date', 'Flow Rate (cfs)']]

P_10 = pd.read_csv('P10-20341747_clean.csv')
P_10 = P_10.rename(columns={'Date, GMT-06:00':'Date'})
P_10['Date'] = pd.to_datetime(P_10['Date'])

P_10 = pd.merge(P_10, p_10, on='Date', how='left')

# UPDATING CLEANED FILE
new.to_csv('P10-20341747_clean.csv')

# %%
# MERGING MANUALLY COLLECTED DISCHARGE INTO CLEANED DATALOGGER P-12 DISCHARGE
p_12 = pd.read_excel('Discharge vs Stage 2022.xlsx', sheet_name= 'P-12')
p_12 = p_12[['Date', 'Flow Rate (cfs)']]
p_12['Date'] = p_12['Date'].dt.strftime('%Y-%m-%d')
p_12['Date'] = pd.to_datetime(p_12['Date'])

P_12 = pd.read_csv('P12_-_PPC_at_mouth_clean.csv')
P_12 = P_12.rename(columns={'Date, GMT-06:00':'Date'})
P_12['Date'] = pd.to_datetime(P_12['Date'])

new = pd.merge(P_12, p_12, on='Date', how='left')

# UPDATING CLEANED FILE
new.to_csv('P12_-_PPC_at_mouth_clean.csv')

# %%
# MERGING MANUALLY COLLECTED DISCHARGE INTO CLEANED DATALOGGER T-4 DISCHARGE
t_4 = pd.read_excel('Discharge vs Stage 2022.xlsx', sheet_name= 'T-4')
t_4 = t_4[['Date', 'Flow Rate (cfs)']]
t_4['Date'] = t_4['Date'].dt.strftime('%Y-%m-%d')
t_4['Date'] = pd.to_datetime(t_4['Date'])

T_4 = pd.read_csv('T4_TMC_@_Green_Meadow_clean.csv')
T_4 = T_4.rename(columns={'Date, GMT-06:00':'Date'})
T_4['Date'] = pd.to_datetime(T_4['Date'])

new = pd.merge(T_4, t_4, on='Date', how='left')

# UPDATING CLEANED FILE
new.to_csv('T4_TMC_@_Green_Meadow_clean.csv')

# %%
# MERGING MANUALLY COLLECTED DISCHARGE INTO CLEANED DATALOGGER T-4.2 DISCHARGE
t_42 = pd.read_excel('Discharge vs Stage 2022.xlsx', sheet_name= 'T-4.2')
t_42 = t_42[['Date', 'Flow Rate (cfs)']]
t_42['Date'] = t_42['Date'].dt.strftime('%Y-%m-%d')
t_42['Date'] = pd.to_datetime(t_42['Date'])

T_42 = pd.read_csv('T4.2_TMC_@_N_Montana_clean.csv')
T_42 = T_42.rename(columns={'Date, GMT-06:00':'Date'})
T_42['Date'] = pd.to_datetime(T_42['Date'])

new = pd.merge(T_42, t_42, on='Date', how='left')

# UPDATING CLEANED FILE
new.to_csv('T4.2_TMC_@_N_Montana_clean.csv')

# %%
# MERGING MANUALLY COLLECTED DISCHARGE INTO CLEANED T-7 DATALOGGER DISCHARGE
t_7 = pd.read_excel('Discharge vs Stage 2022.xlsx', sheet_name= 'T-7')
t_7 = t_7[['Date', 'Flow Rate (cfs)']]
t_7['Date'] = t_7['Date'].dt.strftime('%Y-%m-%d')
t_7['Date'] = pd.to_datetime(t_7['Date'])

T_7 = pd.read_csv('T7_Tenmile_Creek_DS_from_Sierra_Rd_clean.csv')
T_7 = T_7.rename(columns={'Date, GMT-06:00':'Date'})
T_7['Date'] = pd.to_datetime(T_7['Date'])

new = pd.merge(T_7, t_7, on='Date', how='left')

# UPDATING CLEANED FILE
new.to_csv('T7_Tenmile_Creek_DS_from_Sierra_Rd_clean.csv')

# %%
# MERGING MANUALLY COLLECTED DISCHARGE INTO CLEANED SC-1 DATALOGGER DISCHARGE
sc_1 = pd.read_excel('Discharge vs Stage 2022.xlsx', sheet_name= 'SC-1')
sc_1 = sc_1[['Date', 'Flow Rate (cfs)']]

SC_1 = pd.read_csv('SC1_Silver_Creek_US_from_Silver_Creek_Rd_clean.csv')
SC_1 = SC_1.rename(columns={'Date, GMT-06:00':'Date'})
SC_1['Date'] = pd.to_datetime(SC_1['Date'])

new = pd.merge(SC_1, sc_1, on='Date', how='left')

# UPDATING CLEANED FILE
new.to_csv('SC1_Silver_Creek_US_from_Silver_Creek_Rd_clean.csv')

# %%
# MERGING MANUALLY COLLECTED DISCHARGE INTO CLEANED DATALOGGER P-7 DISCHARGE
p_7 = pd.read_excel('Discharge vs Stage 2022.xlsx', sheet_name= 'P-7')
p_7 = p_7[['Date', 'Flow Rate (cfs)']]

P_7 = pd.read_csv('P-7_PPC_at_FAS_York_Rd_clean.csv')
P_7 = P_7.rename(columns={'Date, GMT-06:00':'Date'})
P_7['Date'] = pd.to_datetime(P_7['Date'])

new = pd.merge(P_7, p_7, on='Date', how='left')

# UPDATING CLEANED FILE
new.to_csv('P-7_PPC_at_FAS_York_Rd_clean.csv')
